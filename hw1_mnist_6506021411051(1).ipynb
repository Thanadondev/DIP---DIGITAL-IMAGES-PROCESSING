# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def load_image(file_name):
    with open(file_name, "rb") as f:
        magic_number = int.from_bytes(f.read(4), "big")
        image_count  = int.from_bytes(f.read(4), "big")
        image_row    = int.from_bytes(f.read(4), "big")
        image_column = int.from_bytes(f.read(4), "big")
        image_data   = f.read()
        image        = np.frombuffer(image_data,dtype=np.uint8).reshape(image_count, image_row, image_column)
    return image

def load_label(file_name):
    with open(file_name, "rb") as f:
        magic_number = int.from_bytes(f.read(4), "big")
        image_count  = int.from_bytes(f.read(4), "big")
        image_data   = f.read()
        image        = np.frombuffer(image_data,dtype=np.uint8)
    return image

# %%
train_mnist_img = load_image("./dataset/train-images.idx3-ubyte")
train_mnist_label = load_label("./dataset/train-labels.idx1-ubyte")
test_mnist_img = load_image("./dataset/t10k-images.idx3-ubyte")
test_mnist_label = load_label("./dataset/t10k-labels.idx1-ubyte")

# %% [markdown]
# ＃＃BLOCK 1 แสดง ภาพตัวอย่าง เลขแบบสุ่ม เลขละ 5 ภาพ รวม 50 ภาพ กดแต่ละครั้งต้องไม่ซ้ำ

# %%
random_indices = []
count_dict = {i: 0 for i in range(10)}
consecutive_duplicates = {i: 0 for i in range(10)}
max_consecutive_duplicates = 5  # จำนวนครั้งสูงสุดที่ตัวเลขจะสามารถซ้ำกันได้

while len(random_indices) < 50:
    # สุ่มตัวเลขใหม่
    new_random = np.random.randint(0, 10)
    # ตรวจสอบว่าตัวเลขนี้เกิดขึ้นซ้ำกันเกินจำนวนสูงสุดหรือไม่
    if consecutive_duplicates[new_random] >= max_consecutive_duplicates:
        continue  # ถ้าซ้ำเกินจำนวนสูงสุดให้ข้ามไป
    else:
        consecutive_duplicates[new_random] += 1
    
    # เพิ่มตัวเลขลงในรายการ random_indices
    random_indices.append(new_random)
    count_dict[new_random] += 1

plt.figure(figsize=(10, 10))

for i, idx in enumerate(random_indices):
    plt.subplot(5, 10, i + 1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    im = train_mnist_img[train_mnist_label == idx][count_dict[idx]]
    plt.imshow(im, plt.cm.binary)
    plt.xlabel(idx)
    
for digit, count in count_dict.items():
    print(f'ตัวเลข {digit}: {count} ครั้ง')

plt.show()
# Out:
# ตัวเลข 0: 5 ครั้ง
# ตัวเลข 1: 5 ครั้ง
# ตัวเลข 2: 5 ครั้ง
# ตัวเลข 3: 5 ครั้ง
# ตัวเลข 4: 5 ครั้ง
# ตัวเลข 5: 5 ครั้ง
# ตัวเลข 6: 5 ครั้ง
# ตัวเลข 7: 5 ครั้ง
# ตัวเลข 8: 5 ครั้ง
# ตัวเลข 9: 5 ครั้ง

# %%
#pip install tensorflow เอาไว้ติดตั้วเผื่อไม่มี

# %%
import tensorflow as tf
y_train = tf.keras.utils.to_categorical(train_mnist_label,10)
y_test = tf.keras.utils.to_categorical(test_mnist_label,10)
train_data = train_mnist_img.reshape(train_mnist_img.shape[0],-1)
test_data = test_mnist_img.reshape(test_mnist_img.shape[0],-1)

# %%
model = tf.keras.Sequential()
model.add(tf.keras.layers.Dense(units = 1025,input_shape=(784,), activation=tf.keras.activations.relu))
model.add(tf.keras.layers.Dense(units = 255, activation=tf.keras.activations.relu))
model.add(tf.keras.layers.Dense(units = 10, activation=tf.keras.activations.softmax))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 1025)              804625
#
#  dense_1 (Dense)             (None, 255)               261630
#
#  dense_2 (Dense)             (None, 10)                2560
#
# =================================================================
# Total params: 1068815 (4.08 MB)
# Trainable params: 1068815 (4.08 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=1e-3),
    loss = tf.keras.losses.categorical_crossentropy,
    metrics = [tf.keras.metrics.categorical_accuracy]
    )

# %%
history = model.fit(train_data, 
                    y_train, 
                    batch_size=1000, 
                    shuffle=True, 
                    epochs=200
                    )
# Out:
# Epoch 1/200
# 60/60 [==============================] - 2s 29ms/step - loss: 7.0789e-05 - categorical_accuracy: 1.0000
# Epoch 2/200
# 60/60 [==============================] - 2s 34ms/step - loss: 6.7840e-05 - categorical_accuracy: 1.0000
# Epoch 3/200
# 60/60 [==============================] - 2s 37ms/step - loss: 6.5303e-05 - categorical_accuracy: 1.0000
# Epoch 4/200
# 60/60 [==============================] - 2s 29ms/step - loss: 6.2755e-05 - categorical_accuracy: 1.0000
# Epoch 5/200
# 60/60 [==============================] - 2s 31ms/step - loss: 6.0657e-05 - categorical_accuracy: 1.0000
# Epoch 6/200
# 60/60 [==============================] - 2s 31ms/step - loss: 5.8208e-05 - categorical_accuracy: 1.0000
# Epoch 7/200
# 60/60 [==============================] - 2s 30ms/step - loss: 5.5917e-05 - categorical_accuracy: 1.0000
# Epoch 8/200
# 60/60 [==============================] - 2s 28ms/step - loss: 5.4239e-05 - categorical_accuracy: 1.0000
# Epoch 9/200
# 60/60 [==============================] - 2s 27ms/step - loss: 5.2502e-05 - categorical_accuracy: 1.0000
# Epoch 10/200
# 60/60 [==============================] - 2s 28ms/step - loss: 5.0294e-05 - categorical_accuracy: 1.0000
# Epoch 11/200
# 60/60 [==============================] - 2s 31ms/step - loss: 4.8440e-05 - categorical_accuracy: 1.0000
# Epoch 12/200
# 60/60 [==============================] - 2s 36ms/step - loss: 4.6697e-05 - categorical_accuracy: 1.0000
# Epoch 13/200
# 60/60 [==============================] - 2s 36ms/step - loss: 4.5062e-05 - categorical_accuracy: 1.0000
# Epoch 14/200
# 60/60 [==============================] - 2s 33ms/step - loss: 4.3750e-05 - categorical_accuracy: 1.0000
# Epoch 15/200
# 60/60 [==============================] - 2s 32ms/step - loss: 4.2128e-05 - categorical_accuracy: 1.0000
# Epoch 16/200
# 60/60 [==============================] - 2s 30ms/step - loss: 4.0998e-05 - categorical_accuracy: 1.0000
# Epoch 17/200
# 60/60 [==============================] - 2s 29ms/step - loss: 3.9273e-05 - categorical_accuracy: 1.0000
# Epoch 18/200
# 60/60 [==============================] - 2s 30ms/step - loss: 3.7769e-05 - categorical_accuracy: 1.0000
# Epoch 19/200
# 60/60 [==============================] - 2s 31ms/step - loss: 3.6672e-05 - categorical_accuracy: 1.0000
# Epoch 20/200
# 60/60 [==============================] - 2s 31ms/step - loss: 3.5501e-05 - categorical_accuracy: 1.0000
# Epoch 21/200
# 60/60 [==============================] - 2s 34ms/step - loss: 3.4200e-05 - categorical_accuracy: 1.0000
# Epoch 22/200
# 60/60 [==============================] - 2s 33ms/step - loss: 3.2973e-05 - categorical_accuracy: 1.0000
# Epoch 23/200
# 60/60 [==============================] - 2s 33ms/step - loss: 3.2067e-05 - categorical_accuracy: 1.0000
# Epoch 24/200
# 60/60 [==============================] - 2s 34ms/step - loss: 3.0911e-05 - categorical_accuracy: 1.0000
# Epoch 25/200
# 60/60 [==============================] - 2s 32ms/step - loss: 2.9789e-05 - categorical_accuracy: 1.0000
# Epoch 26/200
# 60/60 [==============================] - 2s 31ms/step - loss: 2.8902e-05 - categorical_accuracy: 1.0000
# Epoch 27/200
# 60/60 [==============================] - 2s 32ms/step - loss: 2.7930e-05 - categorical_accuracy: 1.0000
# Epoch 28/200
# 60/60 [==============================] - 2s 34ms/step - loss: 2.6937e-05 - categorical_accuracy: 1.0000
# Epoch 29/200
# 60/60 [==============================] - 2s 32ms/step - loss: 2.6086e-05 - categorical_accuracy: 1.0000
# Epoch 30/200
# 60/60 [==============================] - 2s 31ms/step - loss: 2.5238e-05 - categorical_accuracy: 1.0000
# Epoch 31/200
# 60/60 [==============================] - 2s 30ms/step - loss: 2.4407e-05 - categorical_accuracy: 1.0000
# Epoch 32/200
# 60/60 [==============================] - 2s 31ms/step - loss: 2.3694e-05 - categorical_accuracy: 1.0000
# Epoch 33/200
# 60/60 [==============================] - 2s 30ms/step - loss: 2.2914e-05 - categorical_accuracy: 1.0000
# Epoch 34/200
# 60/60 [==============================] - 2s 29ms/step - loss: 2.2051e-05 - categorical_accuracy: 1.0000
# Epoch 35/200
# 60/60 [==============================] - 2s 32ms/step - loss: 2.1469e-05 - categorical_accuracy: 1.0000
# Epoch 36/200
# 60/60 [==============================] - 2s 31ms/step - loss: 2.0707e-05 - categorical_accuracy: 1.0000
# Epoch 37/200
# 60/60 [==============================] - 2s 41ms/step - loss: 2.0019e-05 - categorical_accuracy: 1.0000
# Epoch 38/200
# 60/60 [==============================] - 2s 39ms/step - loss: 1.9377e-05 - categorical_accuracy: 1.0000
# Epoch 39/200
# 60/60 [==============================] - 2s 36ms/step - loss: 1.8874e-05 - categorical_accuracy: 1.0000
# Epoch 40/200
# 60/60 [==============================] - 2s 33ms/step - loss: 1.8169e-05 - categorical_accuracy: 1.0000
# Epoch 41/200
# 60/60 [==============================] - 2s 29ms/step - loss: 1.7635e-05 - categorical_accuracy: 1.0000
# Epoch 42/200
# 60/60 [==============================] - 2s 28ms/step - loss: 1.7042e-05 - categorical_accuracy: 1.0000
# Epoch 43/200
# 60/60 [==============================] - 2s 28ms/step - loss: 1.6501e-05 - categorical_accuracy: 1.0000
# Epoch 44/200
# 60/60 [==============================] - 2s 28ms/step - loss: 1.6011e-05 - categorical_accuracy: 1.0000
# Epoch 45/200
# 60/60 [==============================] - 2s 32ms/step - loss: 1.5518e-05 - categorical_accuracy: 1.0000
# Epoch 46/200
# 60/60 [==============================] - 2s 34ms/step - loss: 1.4985e-05 - categorical_accuracy: 1.0000
# Epoch 47/200
# 60/60 [==============================] - 2s 35ms/step - loss: 1.4447e-05 - categorical_accuracy: 1.0000
# Epoch 48/200
# 60/60 [==============================] - 2s 33ms/step - loss: 1.4019e-05 - categorical_accuracy: 1.0000
# Epoch 49/200
# 60/60 [==============================] - 2s 33ms/step - loss: 1.3667e-05 - categorical_accuracy: 1.0000
# Epoch 50/200
# 60/60 [==============================] - 2s 30ms/step - loss: 1.3152e-05 - categorical_accuracy: 1.0000
# Epoch 51/200
# 60/60 [==============================] - 2s 30ms/step - loss: 1.2725e-05 - categorical_accuracy: 1.0000
# Epoch 52/200
# 60/60 [==============================] - 2s 35ms/step - loss: 1.2293e-05 - categorical_accuracy: 1.0000
# Epoch 53/200
# 60/60 [==============================] - 2s 31ms/step - loss: 1.1925e-05 - categorical_accuracy: 1.0000
# Epoch 54/200
# 60/60 [==============================] - 2s 35ms/step - loss: 1.1570e-05 - categorical_accuracy: 1.0000
# Epoch 55/200
# 60/60 [==============================] - 2s 35ms/step - loss: 1.1143e-05 - categorical_accuracy: 1.0000
# Epoch 56/200
# 60/60 [==============================] - 2s 34ms/step - loss: 1.0822e-05 - categorical_accuracy: 1.0000
# Epoch 57/200
# 60/60 [==============================] - 2s 32ms/step - loss: 1.0444e-05 - categorical_accuracy: 1.0000
# Epoch 58/200
# 60/60 [==============================] - 2s 30ms/step - loss: 1.0158e-05 - categorical_accuracy: 1.0000
# Epoch 59/200
# 60/60 [==============================] - 2s 31ms/step - loss: 9.8287e-06 - categorical_accuracy: 1.0000
# Epoch 60/200
# 60/60 [==============================] - 2s 30ms/step - loss: 9.5093e-06 - categorical_accuracy: 1.0000
# Epoch 61/200
# 60/60 [==============================] - 2s 32ms/step - loss: 9.2241e-06 - categorical_accuracy: 1.0000
# Epoch 62/200
# 60/60 [==============================] - 3s 41ms/step - loss: 8.9082e-06 - categorical_accuracy: 1.0000
# Epoch 63/200
# 60/60 [==============================] - 2s 36ms/step - loss: 8.6755e-06 - categorical_accuracy: 1.0000
# Epoch 64/200
# 60/60 [==============================] - 2s 31ms/step - loss: 8.3807e-06 - categorical_accuracy: 1.0000
# Epoch 65/200
# 60/60 [==============================] - 2s 30ms/step - loss: 8.1291e-06 - categorical_accuracy: 1.0000
# Epoch 66/200
# 60/60 [==============================] - 2s 29ms/step - loss: 7.8459e-06 - categorical_accuracy: 1.0000
# Epoch 67/200
# 60/60 [==============================] - 2s 29ms/step - loss: 7.6367e-06 - categorical_accuracy: 1.0000
# Epoch 68/200
# 60/60 [==============================] - 2s 29ms/step - loss: 7.3866e-06 - categorical_accuracy: 1.0000
# Epoch 69/200
# 60/60 [==============================] - 2s 29ms/step - loss: 7.1477e-06 - categorical_accuracy: 1.0000
# Epoch 70/200
# 60/60 [==============================] - 2s 35ms/step - loss: 6.9206e-06 - categorical_accuracy: 1.0000
# Epoch 71/200
# 60/60 [==============================] - 2s 39ms/step - loss: 6.7086e-06 - categorical_accuracy: 1.0000
# Epoch 72/200
# 60/60 [==============================] - 2s 33ms/step - loss: 6.5072e-06 - categorical_accuracy: 1.0000
# Epoch 73/200
# 60/60 [==============================] - 2s 33ms/step - loss: 6.3022e-06 - categorical_accuracy: 1.0000
# Epoch 74/200
# 60/60 [==============================] - 2s 30ms/step - loss: 6.1152e-06 - categorical_accuracy: 1.0000
# Epoch 75/200
# 60/60 [==============================] - 2s 31ms/step - loss: 5.9157e-06 - categorical_accuracy: 1.0000
# Epoch 76/200
# 60/60 [==============================] - 2s 29ms/step - loss: 5.7319e-06 - categorical_accuracy: 1.0000
# Epoch 77/200
# 60/60 [==============================] - 2s 29ms/step - loss: 5.5511e-06 - categorical_accuracy: 1.0000
# Epoch 78/200
# 60/60 [==============================] - 2s 36ms/step - loss: 5.3843e-06 - categorical_accuracy: 1.0000
# Epoch 79/200
# 60/60 [==============================] - 3s 43ms/step - loss: 5.2038e-06 - categorical_accuracy: 1.0000
# Epoch 80/200
# 60/60 [==============================] - 2s 40ms/step - loss: 5.0562e-06 - categorical_accuracy: 1.0000
# Epoch 81/200
# 60/60 [==============================] - 2s 31ms/step - loss: 4.8831e-06 - categorical_accuracy: 1.0000
# Epoch 82/200
# 60/60 [==============================] - 2s 28ms/step - loss: 4.7501e-06 - categorical_accuracy: 1.0000
# Epoch 83/200
# 60/60 [==============================] - 2s 27ms/step - loss: 4.5964e-06 - categorical_accuracy: 1.0000
# Epoch 84/200
# 60/60 [==============================] - 2s 27ms/step - loss: 4.4678e-06 - categorical_accuracy: 1.0000
# Epoch 85/200
# 60/60 [==============================] - 2s 28ms/step - loss: 4.3185e-06 - categorical_accuracy: 1.0000
# Epoch 86/200
# 60/60 [==============================] - 2s 32ms/step - loss: 4.1729e-06 - categorical_accuracy: 1.0000
# Epoch 87/200
# 60/60 [==============================] - 2s 37ms/step - loss: 4.0369e-06 - categorical_accuracy: 1.0000
# Epoch 88/200
# 60/60 [==============================] - 2s 31ms/step - loss: 3.9297e-06 - categorical_accuracy: 1.0000
# Epoch 89/200
# 60/60 [==============================] - 2s 30ms/step - loss: 3.8322e-06 - categorical_accuracy: 1.0000
# Epoch 90/200
# 60/60 [==============================] - 2s 29ms/step - loss: 3.6903e-06 - categorical_accuracy: 1.0000
# Epoch 91/200
# 60/60 [==============================] - 2s 27ms/step - loss: 3.5744e-06 - categorical_accuracy: 1.0000
# Epoch 92/200
# 60/60 [==============================] - 2s 27ms/step - loss: 3.4681e-06 - categorical_accuracy: 1.0000
# Epoch 93/200
# 60/60 [==============================] - 2s 27ms/step - loss: 3.3524e-06 - categorical_accuracy: 1.0000
# Epoch 94/200
# 60/60 [==============================] - 2s 31ms/step - loss: 3.2593e-06 - categorical_accuracy: 1.0000
# Epoch 95/200
# 60/60 [==============================] - 2s 32ms/step - loss: 3.1590e-06 - categorical_accuracy: 1.0000
# Epoch 96/200
# 60/60 [==============================] - 2s 32ms/step - loss: 3.0427e-06 - categorical_accuracy: 1.0000
# Epoch 97/200
# 60/60 [==============================] - 2s 31ms/step - loss: 2.9559e-06 - categorical_accuracy: 1.0000
# Epoch 98/200
# 60/60 [==============================] - 2s 29ms/step - loss: 2.8714e-06 - categorical_accuracy: 1.0000
# Epoch 99/200
# 60/60 [==============================] - 2s 31ms/step - loss: 2.7805e-06 - categorical_accuracy: 1.0000
# Epoch 100/200
# 60/60 [==============================] - 2s 32ms/step - loss: 2.6951e-06 - categorical_accuracy: 1.0000
# Epoch 101/200
# 60/60 [==============================] - 2s 30ms/step - loss: 2.5989e-06 - categorical_accuracy: 1.0000
# Epoch 102/200
# 60/60 [==============================] - 2s 28ms/step - loss: 2.5178e-06 - categorical_accuracy: 1.0000
# Epoch 103/200
# 60/60 [==============================] - 2s 29ms/step - loss: 2.4450e-06 - categorical_accuracy: 1.0000
# Epoch 104/200
# 60/60 [==============================] - 2s 30ms/step - loss: 2.3782e-06 - categorical_accuracy: 1.0000
# Epoch 105/200
# 60/60 [==============================] - 2s 28ms/step - loss: 2.3053e-06 - categorical_accuracy: 1.0000
# Epoch 106/200
# 60/60 [==============================] - 2s 29ms/step - loss: 2.2177e-06 - categorical_accuracy: 1.0000
# Epoch 107/200
# 60/60 [==============================] - 2s 28ms/step - loss: 2.1568e-06 - categorical_accuracy: 1.0000
# Epoch 108/200
# 60/60 [==============================] - 2s 28ms/step - loss: 2.0838e-06 - categorical_accuracy: 1.0000
# Epoch 109/200
# 60/60 [==============================] - 2s 27ms/step - loss: 2.0200e-06 - categorical_accuracy: 1.0000
# Epoch 110/200
# 60/60 [==============================] - 2s 28ms/step - loss: 1.9581e-06 - categorical_accuracy: 1.0000
# Epoch 111/200
# 60/60 [==============================] - 2s 29ms/step - loss: 1.8993e-06 - categorical_accuracy: 1.0000
# Epoch 112/200
# 60/60 [==============================] - 2s 35ms/step - loss: 1.8446e-06 - categorical_accuracy: 1.0000
# Epoch 113/200
# 60/60 [==============================] - 2s 32ms/step - loss: 1.7846e-06 - categorical_accuracy: 1.0000
# Epoch 114/200
# 60/60 [==============================] - 2s 34ms/step - loss: 1.7302e-06 - categorical_accuracy: 1.0000
# Epoch 115/200
# 60/60 [==============================] - 2s 32ms/step - loss: 1.6801e-06 - categorical_accuracy: 1.0000
# Epoch 116/200
# 60/60 [==============================] - 2s 29ms/step - loss: 1.6301e-06 - categorical_accuracy: 1.0000
# Epoch 117/200
# 60/60 [==============================] - 2s 30ms/step - loss: 1.5777e-06 - categorical_accuracy: 1.0000
# Epoch 118/200
# 60/60 [==============================] - 2s 27ms/step - loss: 1.5308e-06 - categorical_accuracy: 1.0000
# Epoch 119/200
# 60/60 [==============================] - 2s 27ms/step - loss: 1.4856e-06 - categorical_accuracy: 1.0000
# Epoch 120/200
# 60/60 [==============================] - 2s 28ms/step - loss: 1.4312e-06 - categorical_accuracy: 1.0000
# Epoch 121/200
# 60/60 [==============================] - 2s 31ms/step - loss: 1.3885e-06 - categorical_accuracy: 1.0000
# Epoch 122/200
# 60/60 [==============================] - 3s 44ms/step - loss: 1.3482e-06 - categorical_accuracy: 1.0000
# Epoch 123/200
# 60/60 [==============================] - 2s 37ms/step - loss: 1.3069e-06 - categorical_accuracy: 1.0000
# Epoch 124/200
# 60/60 [==============================] - 2s 30ms/step - loss: 1.2651e-06 - categorical_accuracy: 1.0000
# Epoch 125/200
# 60/60 [==============================] - 2s 29ms/step - loss: 1.2266e-06 - categorical_accuracy: 1.0000
# Epoch 126/200
# 60/60 [==============================] - 2s 30ms/step - loss: 1.1972e-06 - categorical_accuracy: 1.0000
# Epoch 127/200
# 60/60 [==============================] - 2s 29ms/step - loss: 1.1542e-06 - categorical_accuracy: 1.0000
# Epoch 128/200
# 60/60 [==============================] - 2s 27ms/step - loss: 1.1133e-06 - categorical_accuracy: 1.0000
# Epoch 129/200
# 60/60 [==============================] - 2s 34ms/step - loss: 1.0833e-06 - categorical_accuracy: 1.0000
# Epoch 130/200
# 60/60 [==============================] - 2s 32ms/step - loss: 1.0500e-06 - categorical_accuracy: 1.0000
# Epoch 131/200
# 60/60 [==============================] - 2s 33ms/step - loss: 1.0183e-06 - categorical_accuracy: 1.0000
# Epoch 132/200
# 60/60 [==============================] - 2s 32ms/step - loss: 9.8567e-07 - categorical_accuracy: 1.0000
# Epoch 133/200
# 60/60 [==============================] - 2s 32ms/step - loss: 9.5766e-07 - categorical_accuracy: 1.0000
# Epoch 134/200
# 60/60 [==============================] - 2s 29ms/step - loss: 9.2851e-07 - categorical_accuracy: 1.0000
# Epoch 135/200
# 60/60 [==============================] - 2s 28ms/step - loss: 8.9666e-07 - categorical_accuracy: 1.0000
# Epoch 136/200
# 60/60 [==============================] - 2s 27ms/step - loss: 8.7060e-07 - categorical_accuracy: 1.0000
# Epoch 137/200
# 60/60 [==============================] - 2s 27ms/step - loss: 8.4347e-07 - categorical_accuracy: 1.0000
# Epoch 138/200
# 60/60 [==============================] - 2s 27ms/step - loss: 8.1668e-07 - categorical_accuracy: 1.0000
# Epoch 139/200
# 60/60 [==============================] - 2s 29ms/step - loss: 7.9250e-07 - categorical_accuracy: 1.0000
# Epoch 140/200
# 60/60 [==============================] - 2s 29ms/step - loss: 7.6810e-07 - categorical_accuracy: 1.0000
# Epoch 141/200
# 60/60 [==============================] - 2s 29ms/step - loss: 7.4628e-07 - categorical_accuracy: 1.0000
# Epoch 142/200
# 60/60 [==============================] - 2s 30ms/step - loss: 7.2006e-07 - categorical_accuracy: 1.0000
# Epoch 143/200
# 60/60 [==============================] - 2s 29ms/step - loss: 6.9663e-07 - categorical_accuracy: 1.0000
# Epoch 144/200
# 60/60 [==============================] - 2s 28ms/step - loss: 6.7872e-07 - categorical_accuracy: 1.0000
# Epoch 145/200
# 60/60 [==============================] - 2s 29ms/step - loss: 6.5876e-07 - categorical_accuracy: 1.0000
# Epoch 146/200
# 60/60 [==============================] - 2s 29ms/step - loss: 6.3741e-07 - categorical_accuracy: 1.0000
# Epoch 147/200
# 60/60 [==============================] - 2s 31ms/step - loss: 6.1363e-07 - categorical_accuracy: 1.0000
# Epoch 148/200
# 60/60 [==============================] - 2s 41ms/step - loss: 5.9468e-07 - categorical_accuracy: 1.0000
# Epoch 149/200
# 60/60 [==============================] - 2s 31ms/step - loss: 5.7505e-07 - categorical_accuracy: 1.0000
# Epoch 150/200
# 60/60 [==============================] - 2s 38ms/step - loss: 5.5834e-07 - categorical_accuracy: 1.0000
# Epoch 151/200
# 60/60 [==============================] - 2s 31ms/step - loss: 5.4072e-07 - categorical_accuracy: 1.0000
# Epoch 152/200
# 60/60 [==============================] - 2s 30ms/step - loss: 5.2484e-07 - categorical_accuracy: 1.0000
# Epoch 153/200
# 60/60 [==============================] - 2s 29ms/step - loss: 5.0737e-07 - categorical_accuracy: 1.0000
# Epoch 154/200
# 60/60 [==============================] - 2s 28ms/step - loss: 4.9381e-07 - categorical_accuracy: 1.0000
# Epoch 155/200
# 60/60 [==============================] - 2s 30ms/step - loss: 4.7714e-07 - categorical_accuracy: 1.0000
# Epoch 156/200
# 60/60 [==============================] - 2s 34ms/step - loss: 4.6183e-07 - categorical_accuracy: 1.0000
# Epoch 157/200
# 60/60 [==============================] - 2s 35ms/step - loss: 4.4825e-07 - categorical_accuracy: 1.0000
# Epoch 158/200
# 60/60 [==============================] - 2s 34ms/step - loss: 4.3408e-07 - categorical_accuracy: 1.0000
# Epoch 159/200
# 60/60 [==============================] - 2s 32ms/step - loss: 4.1965e-07 - categorical_accuracy: 1.0000
# Epoch 160/200
# 60/60 [==============================] - 2s 31ms/step - loss: 4.0904e-07 - categorical_accuracy: 1.0000
# Epoch 161/200
# 60/60 [==============================] - 2s 29ms/step - loss: 3.9540e-07 - categorical_accuracy: 1.0000
# Epoch 162/200
# 60/60 [==============================] - 2s 29ms/step - loss: 3.8221e-07 - categorical_accuracy: 1.0000
# Epoch 163/200
# 60/60 [==============================] - 2s 29ms/step - loss: 3.7087e-07 - categorical_accuracy: 1.0000
# Epoch 164/200
# 60/60 [==============================] - 2s 32ms/step - loss: 3.5863e-07 - categorical_accuracy: 1.0000
# Epoch 165/200
# 60/60 [==============================] - 2s 34ms/step - loss: 3.4752e-07 - categorical_accuracy: 1.0000
# Epoch 166/200
# 60/60 [==============================] - 2s 34ms/step - loss: 3.3700e-07 - categorical_accuracy: 1.0000
# Epoch 167/200
# 60/60 [==============================] - 2s 32ms/step - loss: 3.2740e-07 - categorical_accuracy: 1.0000
# Epoch 168/200
# 60/60 [==============================] - 2s 33ms/step - loss: 3.1862e-07 - categorical_accuracy: 1.0000
# Epoch 169/200
# 60/60 [==============================] - 2s 30ms/step - loss: 3.0779e-07 - categorical_accuracy: 1.0000
# Epoch 170/200
# 60/60 [==============================] - 2s 28ms/step - loss: 2.9743e-07 - categorical_accuracy: 1.0000
# Epoch 171/200
# 60/60 [==============================] - 2s 28ms/step - loss: 2.8870e-07 - categorical_accuracy: 1.0000
# Epoch 172/200
# 60/60 [==============================] - 2s 30ms/step - loss: 2.7818e-07 - categorical_accuracy: 1.0000
# Epoch 173/200
# 60/60 [==============================] - 2s 33ms/step - loss: 2.7047e-07 - categorical_accuracy: 1.0000
# Epoch 174/200
# 60/60 [==============================] - 2s 41ms/step - loss: 2.6331e-07 - categorical_accuracy: 1.0000
# Epoch 175/200
# 60/60 [==============================] - 3s 44ms/step - loss: 2.5317e-07 - categorical_accuracy: 1.0000
# Epoch 176/200
# 60/60 [==============================] - 2s 36ms/step - loss: 2.4562e-07 - categorical_accuracy: 1.0000
# Epoch 177/200
# 60/60 [==============================] - 2s 35ms/step - loss: 2.3857e-07 - categorical_accuracy: 1.0000
# Epoch 178/200
# 60/60 [==============================] - 2s 33ms/step - loss: 2.3217e-07 - categorical_accuracy: 1.0000
# Epoch 179/200
# 60/60 [==============================] - 2s 31ms/step - loss: 2.2448e-07 - categorical_accuracy: 1.0000
# Epoch 180/200
# 60/60 [==============================] - 2s 29ms/step - loss: 2.1769e-07 - categorical_accuracy: 1.0000
# Epoch 181/200
# 60/60 [==============================] - 2s 29ms/step - loss: 2.1059e-07 - categorical_accuracy: 1.0000
# Epoch 182/200
# 60/60 [==============================] - 2s 34ms/step - loss: 2.0456e-07 - categorical_accuracy: 1.0000
# Epoch 183/200
# 60/60 [==============================] - 2s 33ms/step - loss: 1.9765e-07 - categorical_accuracy: 1.0000
# Epoch 184/200
# 60/60 [==============================] - 2s 34ms/step - loss: 1.9203e-07 - categorical_accuracy: 1.0000
# Epoch 185/200
# 60/60 [==============================] - 2s 30ms/step - loss: 1.8569e-07 - categorical_accuracy: 1.0000
# Epoch 186/200
# 60/60 [==============================] - 2s 30ms/step - loss: 1.8010e-07 - categorical_accuracy: 1.0000
# Epoch 187/200
# 60/60 [==============================] - 2s 29ms/step - loss: 1.7546e-07 - categorical_accuracy: 1.0000
# Epoch 188/200
# 60/60 [==============================] - 2s 28ms/step - loss: 1.6985e-07 - categorical_accuracy: 1.0000
# Epoch 189/200
# 60/60 [==============================] - 2s 30ms/step - loss: 1.6402e-07 - categorical_accuracy: 1.0000
# Epoch 190/200
# 60/60 [==============================] - 2s 30ms/step - loss: 1.5918e-07 - categorical_accuracy: 1.0000
# Epoch 191/200
# 60/60 [==============================] - 2s 30ms/step - loss: 1.5412e-07 - categorical_accuracy: 1.0000
# Epoch 192/200
# 60/60 [==============================] - 2s 29ms/step - loss: 1.4930e-07 - categorical_accuracy: 1.0000
# Epoch 193/200
# 60/60 [==============================] - 2s 30ms/step - loss: 1.4439e-07 - categorical_accuracy: 1.0000
# Epoch 194/200
# 60/60 [==============================] - 2s 29ms/step - loss: 1.4045e-07 - categorical_accuracy: 1.0000
# Epoch 195/200
# 60/60 [==============================] - 2s 28ms/step - loss: 1.3632e-07 - categorical_accuracy: 1.0000
# Epoch 196/200
# 60/60 [==============================] - 2s 28ms/step - loss: 1.3131e-07 - categorical_accuracy: 1.0000
# Epoch 197/200
# 60/60 [==============================] - 2s 32ms/step - loss: 1.2745e-07 - categorical_accuracy: 1.0000
# Epoch 198/200
# 60/60 [==============================] - 2s 33ms/step - loss: 1.2375e-07 - categorical_accuracy: 1.0000
# Epoch 199/200
# 60/60 [==============================] - 2s 33ms/step - loss: 1.1966e-07 - categorical_accuracy: 1.0000
# Epoch 200/200
# 60/60 [==============================] - 2s 31ms/step - loss: 1.1573e-07 - categorical_accuracy: 1.0000

# %% [markdown]
# ____________________________________________________________________________________________________
# ##BLOCK 2 แสดง ค่าความแม่นยำของ model

# %%
_, acc = model.evaluate(train_data, y_train)
print(acc," OR ",(acc*100),"%")
# Out:
# 1875/1875 [==============================] - 4s 2ms/step - loss: 1.1055e-07 - categorical_accuracy: 1.0000
# 1.0  OR  100.0 %

# %% [markdown]
# #ลองทดสอบ BLOCK2 ดู ว่าถูกต้องไหม

# %%
idx = np.random.randint(1,10000,1)
data = train_data[idx]
result = model.predict(data)
show_label = np.argmax(result)
#               ค่าพยากรณ์                   ผลเฉลย
plt.title(f"predict={show_label} result={train_mnist_label[idx]}")
plt.imshow(train_mnist_img[idx][0],plt.cm.binary)
plt.axis("off")
# Out:
# 1/1 [==============================] - 0s 17ms/step
# (-0.5, 27.5, 27.5, -0.5)

# %% [markdown]
# ______________________________________________________________________________________________________________________________________
# ##BLOCK 3 แสดง ผลการพิสูจน์ เลข จากชุด test dataset ทุกเลข 10000 ค่า

# %%
wrong = 0
correct = 0
for i in range(1000):
    idx = np.random.randint(1,10000,1)
    data = test_data[idx]
    result = model.predict(data, verbose=0)
    p_class = np.argmax(result)
    ans = test_mnist_label[idx]
    if(p_class != ans):
        wrong = wrong+1
        print("Num of Wrong :",wrong," Number :" , p_class," Result", ans)
    else:
        correct = correct+1
print("\nCheck 1000 Round total correct :",correct," total wrong :",wrong)
# Out:
# Num of Wrong : 1  Number : 3  Result [7]
# Num of Wrong : 2  Number : 7  Result [4]
# Num of Wrong : 3  Number : 3  Result [5]
# Num of Wrong : 4  Number : 2  Result [3]
# Num of Wrong : 5  Number : 5  Result [6]
# Num of Wrong : 6  Number : 8  Result [1]
# Num of Wrong : 7  Number : 3  Result [8]
# Num of Wrong : 8  Number : 4  Result [6]
# Num of Wrong : 9  Number : 3  Result [5]
# Num of Wrong : 10  Number : 4  Result [7]
# Num of Wrong : 11  Number : 3  Result [5]
# Num of Wrong : 12  Number : 9  Result [7]
# Num of Wrong : 13  Number : 4  Result [7]
# Num of Wrong : 14  Number : 8  Result [3]
# Num of Wrong : 15  Number : 8  Result [5]
# Num of Wrong : 16  Number : 6  Result [5]
# Num of Wrong : 17  Number : 4  Result [6]
# Num of Wrong : 18  Number : 5  Result [8]
# Num of Wrong : 19  Number : 5  Result [9]
# Num of Wrong : 20  Number : 9  Result [5]
# Num of Wrong : 21  Number : 7  Result [9]
# Num of Wrong : 22  Number : 9  Result [7]
# Num of Wrong : 23  Number : 3  Result [5]
# Num of Wrong : 24  Number : 4  Result [1]
# Num of Wrong : 25  Number : 4  Result [8]
# Num of Wrong : 26  Number : 5  Result [8]
#
# Check 1000 Round total correct : 974  total wrong : 26

# %% [markdown]
# _______________________________________________________________________________________________
# ##BLOCK 4 เมื่อสุ่ม 100 ค่า จากชุด train ผิดกี่ภาพ

# %%
wrong = 0
for i in range(100):
    idx = np.random.randint(1,10000,1)
    data = train_data[idx]
    result = model.predict(data, verbose=0)
    p_class = np.argmax(result)
    ans = train_mnist_label[idx]
    if(p_class != ans):
        wrong = wrong+1
print("Check train 100 Round"," total wrong : ",wrong)
# Out:
# Check train 100 Round  total wrong :  0

# %% [markdown]
# _____________________________________________________________________________
# ##BLOCK 5 เมื่อสุ่ม 100 ค่า จากชุด test ผิดกี่ภาพ

# %%
wrong = 0
for i in range(100):
    idx = np.random.randint(1,10000,1)
    data = test_data[idx]
    result = model.predict(data, verbose=0)
    p_class = np.argmax(result)
    ans = test_mnist_label[idx]
    if(p_class != ans):
        wrong = wrong+1
print("Check test 100 Round"," total wrong : ",wrong)
# Out:
# Check test 100 Round  total wrong :  1
