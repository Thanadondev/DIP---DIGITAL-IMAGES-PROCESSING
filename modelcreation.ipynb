# %%
# Import libraries
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Conv2D, MaxPooling2D, Flatten, Dropout
from tensorflow.keras.datasets import cifar10
from tensorflow.keras.utils import to_categorical
from sklearn.model_selection import train_test_split

# Load CIFAR-10 dataset
(x_train, y_train), (x_test, y_test) = cifar10.load_data()
y_train = to_categorical(y_train, 10)
y_test = to_categorical(y_test, 10)

# Define and train model1 (NN) with more epochs
model1 = Sequential()
model1.add(Flatten(input_shape=(32, 32, 3)))  # Adjust input shape as needed
model1.add(Dense(512, activation='relu'))
model1.add(Dense(256, activation='relu'))
model1.add(Dense(128, activation='relu'))
model1.add(Dense(64, activation='relu'))
model1.add(Dense(10, activation='softmax'))

model1.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
model1.fit(x_train, y_train, epochs=100, batch_size=1000, shuffle=True, validation_split=0.2)
model1.fit(x_train, y_train, epochs=60, batch_size=750, shuffle=True, validation_split=0.2)
model1.fit(x_train, y_train, epochs=50, batch_size=1500, shuffle=True, validation_split=0.2)
model1.fit(x_train, y_train, epochs=40, batch_size=5000, shuffle=True, validation_split=0.2)




# Save model1
model1.save('model1_6506021411013.h5')

# Define and train model2 (CNN) with more epochs
model2 = Sequential()
model2.add(Conv2D(32, (3, 3), activation='relu', input_shape=(32, 32, 3)))
model2.add(MaxPooling2D((2, 2)))
model2.add(Conv2D(64, (3, 3), activation='relu'))
model2.add(MaxPooling2D((2, 2)))
model2.add(Conv2D(128, (3, 3), activation='relu'))
model2.add(MaxPooling2D((2, 2)))
model2.add(Flatten())
model2.add(Dense(256, activation='relu'))
model2.add(Dense(128, activation='relu'))
model2.add(Dense(10, activation='softmax'))

model2.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
model2.fit(x_train,y_train ,epochs=100,batch_size=500,shuffle=True,validation_split=0.2)
model2.fit(x_train,y_train ,epochs=20,batch_size=1000,shuffle=True,validation_split=0.2)
model2.fit(x_train,y_train ,epochs=20,batch_size=1000,shuffle=True,validation_split=0.2)

# Save model2
model2.save('model2_6506021411013.h5')

# Evaluate model1
accuracy1 = model1.evaluate(x_test, y_test, verbose=0)[1]
print("Accuracy of model1:", accuracy1)

# Evaluate model2
accuracy2 = model2.evaluate(x_test, y_test, verbose=0)[1]
print("Accuracy of model2:", accuracy2)
# Out:
# Epoch 1/100
# 40/40 [==============================] - 5s 86ms/step - loss: 174.5267 - accuracy: 0.1184 - val_loss: 70.0474 - val_accuracy: 0.1109
# Epoch 2/100
# 40/40 [==============================] - 3s 84ms/step - loss: 26.2192 - accuracy: 0.1764 - val_loss: 11.6775 - val_accuracy: 0.2143
# Epoch 3/100
# 40/40 [==============================] - 3s 82ms/step - loss: 15.0501 - accuracy: 0.1890 - val_loss: 20.3592 - val_accuracy: 0.1612
# Epoch 4/100
# 40/40 [==============================] - 3s 84ms/step - loss: 14.4183 - accuracy: 0.2016 - val_loss: 7.1175 - val_accuracy: 0.2070
# Epoch 5/100
# 40/40 [==============================] - 3s 78ms/step - loss: 10.4763 - accuracy: 0.1988 - val_loss: 10.2806 - val_accuracy: 0.2356
# Epoch 6/100
# 40/40 [==============================] - 3s 85ms/step - loss: 5.0461 - accuracy: 0.2461 - val_loss: 3.9362 - val_accuracy: 0.2495
# Epoch 7/100
# ...
